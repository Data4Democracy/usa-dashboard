# %% [markdown]
# # Scrape crime data for San Diego
#
# This notebook accesses data about crime in San Diego here: http://www.sandag.org/programs/public_safety/arjis/CrimeData/crimedata.zip
#
# It then formats this data into a pandas dataframe with the columns: year; month; day; offense; count.
#
# Since they only release 180 days at a time, the first scraper will get all 180 days, and subsequently it can be run to update our database

# %%
# Regular imports
import requests, zipfile, StringIO
import pandas as pd
import numpy as np

# %%
# Load data into a pandas dataframe
zip_file_url = 'http://www.sandag.org/programs/public_safety/arjis/CrimeData/crimedata.zip'
r = requests.get(zip_file_url, stream=True)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
z.extractall()
df = pd.DataFrame.from_csv('./ARJISPublicCrime020817.txt')

# %%
df.head()
# Out:
#               Charge_Description_Orig         activityDate  \
# agency
# NATIONAL CITY   BURGLARY/FIRST DEGREE   10/14/2016 7:00:00
# NATIONAL CITY             PETTY THEFT  11/11/2016 12:00:00
# NATIONAL CITY  BURGLARY/SECOND DEGREE  11/20/2016 19:00:00
# NATIONAL CITY             PETTY THEFT  11/20/2016 12:00:00
# NATIONAL CITY   BURGLARY/FIRST DEGREE   11/2/2016 19:00:00
#
#                                BLOCK_ADDRESS  ZipCode      community
# agency
# NATIONAL CITY    2600  BLOCK PLAZA BOULEVARD  91950.0  NATIONAL CITY
# NATIONAL CITY  3000  BLOCK PLAZA BONITA ROAD  91950.0  NATIONAL CITY
# NATIONAL CITY       500 E  BLOCK 02ND STREET  91950.0  NATIONAL CITY
# NATIONAL CITY      1400 E  BLOCK 06TH STREET  91950.0  NATIONAL CITY
# NATIONAL CITY    2600  BLOCK PLAZA BOULEVARD  91950.0  NATIONAL CITY

# %%
# Extract information for each event: year, month, day, offense
N_records = len(df)
records_dict = {'year': [0]*N_records,
                'month': [0]*N_records,
                'day': [0]*N_records,
                'offense': df['Charge_Description_Orig'].values}

for i in range(N_records):
    date_list = df['activityDate'][i].split('/')
    records_dict['year'][i] = date_list[2].split(' ')[0]
    records_dict['month'][i] = date_list[0]
    records_dict['day'][i] = date_list[1]
    
# Organize data in dataframes, separated by year
df_records = pd.DataFrame.from_dict(records_dict)
df_records_2016 = df_records[df_records['year'].values=='2016']
df_records_2017 = df_records[df_records['year'].values=='2017']

# %%
unique_months = np.unique(df_records_2016['month'].values)
unique_offenses = np.unique(df_records_2016['offense'].values)

# %%
unique_offenses
# Out:
# array([nan, '290 VIOLATION AFTER INCARCERATION (F)',
#        '290 VIOLATION AFTER INCARCERATION (M)',
#        '290 VIOLATION TRAN 30 DAY UPDATE (F)',
#        'ABUSE/CRUELTY TO ELDERLY/DEPENDENT ADULT',
#        'ABUSE/CRUELTY TO ELDERLY/DEPENDENT ADULT WITH GBI LIKELY',
#        'ACQUIRE/ETC PERSONAL IDENTIFYING INFO WITH INTENT TO DEFRAUD',
#        'ADDICT DRIVE VEH (M)',
#        'ADMINISTER/EXPOSE POISON TO ANOTHERS ANIMAL (M)',
#        'ADULT POSS MARIJ ON GROUNDS DURING SCH ACTIVITIES (M)',
#        'ADULT POSSESS MARIJUANA ON GROUNDS DURING SCH ACTIVITIES',
#        'ADW NOT A FIREARM ON P.O./FIREFIGHTER:GBI LIKELY (F)',
#        'ADW ON PEACE OFFICER/FIREMAN/NOT GUN',
#        'ADW ON PEACE OFFICER/FIREMAN/WITH GUN',
#        'ADW TRANSPORTATION WORKER', 'ADW WITH FORCE:POSSIBLE GBI',
#        'ADW WITH FORCE:POSSIBLE GBI (F)',
#        'ADW WITH FORCE:POSSIBLE GBI (M)',
#        'ADW:ASSAULT WITH FIREARM ON PERS (F)',
#        'ADW:ASSAULT:SEMIAUTO:PEACE OFCR/FIREFIGHTER (F)',
#        'AFFIXING GRAFFITI ON REAL OR PERSONAL PROPERTY',
#        'AGGRAVATED MAYHEM', 'AGGRAVATED MAYHEM (F)',
#        'AGGRIVATED ARSON WITH PRIOR',
#        'ALTER CHANGE/ETC IMITATION FIREARM TO LOOK LIKE  FIREARM (M)',
#        'ALTER/CHANGE/ETC IMITATION FIREARM TO LOOK LIKE A FIREARM (M)',
#        'ALTER/ETC ACCESS CARD ACCOUNT INFORMATION',
#        'ALTER/ETC FIREARM ID MARKINGS (F)',
#        'ALTER/REMOVE/ETC IDENTIFICATION MARKS ON FIREARM (F)',
#        'ANNOY/MOLEST CHILD', 'ANNOY/MOLEST CHILDREN UNDER 18 (M)',
#        'ANNOY/MOLEST VICTIM BELIEVED TO BE UNDER 18 YEARS OF AGE (M)',
#        'ANNOY/MOLEST VICTIM UNDER 18 YEARS OF AGE (M)',
#        'ANNOY/MOLESTS VICTIM UNDER 18 YEARS OF AGE',
#        'ARSON INHABITED STRUCTURE OR PROPERTY', 'ARSON OF PROPERTY',
#        'ARSON STRUCTURE OR FOREST LAND',
#        'ARSON:INHABITED STRUCTURE/PROP (F)', 'ARSON:PROP (F)',
#        'ARSON:STRUCTURE/FOREST LAND (F)', 'ASSAULT',
#        'ASSAULT ON PEACE OFFICER/EMERGENCY PERSONNEL',
#        'ASSAULT ON PEACE OFFICER/EMERGENCY PERSONNEL (M)',
#        'ASSAULT ON PEACE OFFICER/EMERGENCY PERSONNEL/ETC (M)',
#        'ASSAULT ON PEACE OFFICER/FIREMAN W/SEMIAUTOMATIC RIFLE',
#        'ASSAULT ON PERS (Simple Assault) (M)', 'ASSAULT ON PERSON',
#        'ASSAULT ON SCHOOL EMPLOYEE', 'ASSAULT ON SCHOOL EMPLOYEE (M)',
#        'ASSAULT OR BATTERY ON SCHOOL PROPERTY (M)',
#        'ASSAULT PERSON WITH A SEMIAUTOMATIC FIREARM (F)',
#        'ASSAULT W/CAUSTIC CHEMICAL',
#        'ASSAULT W/DEADLY WEAPON OTHER THAN FIREARM OR GBI FORCE',
#        'ASSAULT W/DEADLY WEAPON:NOT F/ARM (F)',
#        'ASSAULT W/DEADLY WEAPON:NOT F/ARM (M)',
#        'ASSAULT W/INTENT TO COMMIT FELONY (W/INJ OR WEAPON) (F)',
#        'ASSAULT W/INTENT TO COMMIT RAPE (F)',
#        'ASSAULT W/INTENT TO COMMIT RAPE/OTH SEX ACTS DURING RES 459 (F)',
#        'ASSAULT W/INTENT TO COMMIT RAPE/OTHER SEX ACTS',
#        'ASSAULT WITH A DEADLY WEAPON OR BY FORCE',
#        'ASSAULT WITH CAUSTIC CHEMICAL (F)',
#        'ASSAULT WITH DEADLY WEAPON WITH GUN',
#        'ASSAULT WITH DEADLY WEAPON. MACHINE GUN OR ASSAULT WEAPON',
#        'ASSAULT WITH INTENT TO RAPE',
#        'ASSAULT WITH INTENT TO RAPE IN COMMISSION OF 459',
#        'ASSAULT WITH STUN GUN OR LESS LETHAL WEAPON (M)',
#        'ASSAULT WITH STUN GUN/TASER', 'ASSAULT WITH STUN GUN/TASER (F)',
#        'ATTEMPT BURGLARY', "ATTEMPT OPERATE VEHICLE W/O OWNER'S CONSENT",
#        'ATTEMPT OR AID ARSON (F)',
#        'ATTEMPT TO REMOVE/ETC FIREARM FROM PEACE OFFICER/ETC (F)',
#        'ATTEMPT/AID/COUNSEL/PROCURE ARSON',
#        'ATTEMPTED BURGLARY,FIRST DEGREE',
#        'ATTEMPTED BURGLARY,SECOND DEGREE',
#        'ATTEMPTED BURGLARY:DEGREE UNSPECIFIED', 'ATTEMPTED GRAND THEFT',
#        'ATTEMPTED MURDER', 'ATTEMPTED MURDER (F)',
#        'ATTEMPTED MURDER/DEGREE UNSPECIFIED', 'ATTEMPTED PETTY THEFT',
#        'ATTEMPTED RAPE', 'ATTEMPTED ROBBERY',
#        'ATTEMPTED ROBBERY: FIRST DEGREE',
#        'Alcoholic Beverage Consumption Prohibited in Certain Areas (I)',
#        'BATTERY', 'BATTERY AGAINST A POLICE OFFICER',
#        'BATTERY AGAINST EMERGENCY PERS',
#        'BATTERY AGAINST EMERGENCY PERSON MINOR INJURY (M)',
#        'BATTERY AGAINST EMERGENCY PERSON/ETC',
#        'BATTERY AGAINST POLICE OFFICER',
#        'BATTERY AGAINST POLICE OFFICER WITH MINOR INJURY (F)',
#        'BATTERY AGAINST POLICE OFFICER WITH SERIOUS INJURY (F)',
#        'BATTERY AGAINST SPORTS OFFICIAL (M)',
#        'BATTERY AGAINST TRANSPORTATION WORKERS WITH INJURY',
#        'BATTERY BY GASSING OF PO/DETENTION/INVEST/PROSECUTION EMP',
#        'BATTERY BY GASSING OF PO/DETENTION/INVEST/PROSECUTION EMP (F)',
#        'BATTERY BY GASSING OF PO/DETENTION/INVEST/PROSECUTION EMP (M)',
#        'BATTERY OF ELDER OR DEPENDENT ADULT',
#        'BATTERY ON ANY PERSON ON PUBLIC TRANSPORTATION/PROPERTY',
#        'BATTERY ON CUSTODIAL OFFICER WITH NO INJURY / MINOR INJURY (F)',
#        'BATTERY ON CUSTODIAL OFFICIAL',
#        'BATTERY ON ELDER OR DEPENDENT ADULT WITH NO INJURY / MINOR INJURY (M)',
#        'BATTERY ON NONCOHABITATING FORMER SPOUSE',
#        'BATTERY ON PEACE OFFICER/EMERGENCY PERSONNEL',
#        'BATTERY ON PEACE OFFICER/EMERGENCY PERSONNEL WITH INJURY',
#        'BATTERY ON PEACE OFFICER/EMERGENCY PERSONNEL/ETC (M)',
#        'BATTERY ON PEACE OFFICER/EMERGENCY PERSONNEL/ETC W/INJURY',
#        'BATTERY ON PERSON', 'BATTERY ON PERSON (M)',
#        'BATTERY ON PERSON ON SCHOOL/HOSPITAL/PARK PROPERTY',
#        'BATTERY ON PERSON ON SCHOOL/HOSPITAL/PARK PROPERTY (M)',
#        'BATTERY ON SCHOOL EMPLOYEE', 'BATTERY ON SCHOOL EMPLOYEE (M)',
#        'BATTERY ON TRANSPORTATION PERSONNEL/PASSENGER',
#        'BATTERY W/SER BODILY INJURY (F)',
#        'BATTERY W/SERIOUS BODILY INJURY',
#        'BATTERY WITH SERIOUS BODILY INJURY (F)',
#        'BATTERY WITH SERIOUS BODILY INJURY (PUNISHMENT)',
#        'BATTERY: SPOUSE/EX SPOUSE/DATE/ETC',
#        'BATTERY:SPOUSE/EX SPOUSE/DATE/ETC (M)',
#        'BENEFIT BY FALSE FINANCIAL STATEMENT USING FICT NAME, SSN...',
#        'BRANDISHING FIREARM REPLICA (M)', 'BRANISH FIREARM REPLICA',
#        'BREAK WATER PIPES,ETC', 'BURGLARY (COMMERCIAL) (F)',
#        'BURGLARY (FOR PURPOSE OF FRAUD/FORGERY) (F)',
#        'BURGLARY (RESIDENTIAL) (F)', 'BURGLARY (SHOPLIFTING) (F)',
#        'BURGLARY (SHOPLIFTING) (M)', 'BURGLARY (VEHICLE) (F)',
#        'BURGLARY/ SECOND DEGREE', 'BURGLARY/FIRST DEGREE',
#        'BURGLARY/SECOND DEGREE', 'BURGLARY/UNSPECIFIED',
#        'BURGLARY:UNSPECIFIED', 'CARJACKING', 'CARJACKING (F)',
#        'CARRY A LOADED CONCEALED WEAPON ON PERSON (F)',
#        'CARRY CONCEALED DIRK OR DAGGER',
#        'CARRY CONCEALED DIRK OR DAGGER (F)',
#        'CARRY CONCEALED DIRK OR DAGGER (M)',
#        'CARRY CONCEALED STOLEN WEAPON (F)', 'CARRY CONCEALED WEAPON (M)',
#        'CARRY CONCEALED WEAPON IN VEHICLE (F)',
#        'CARRY CONCEALED WEAPON IN VEHICLE (M)',
#        'CARRY CONCEALED WEAPON IN VEHICLE:OCCUPANT (F)',
#        'CARRY CONCEALED WEAPON IN VEHICLE:OCCUPANT (M',
#        'CARRY CONCEALED WEAPON ON PERSON (F)',
#        'CARRY CONCEALED WEAPON ON PERSON (M)',
#        'CARRY LOAD F/ARM:PRIOR FELONY CONV (F)',
#        'CARRY LOADED F/ARM:GANG MEMBER (F)',
#        'CARRY LOADED FIREARM ON/IN PERSON/VEHICLE:PUBLIC PLACE (M)',
#        'CARRY LOADED FIREARM:IN PUBLIC UNDER SPECIFIC CIRCUMSTANCE',
#        'CARRY LOADED HANDGUN:NOT REGISTERED OWNER (F)',
#        'CARRY STOLEN LOADED FIREARM (F)', 'CARRY SWITCHBLADE KNIFE (M)',
#        'CARRY SWITCHBLADE KNIFE ON PERSON (M)',
#        'CARRY/EXPOSE UNLOADED HANDGUN IN PUBLIC OR A VEHICLE (M)',
#        'CARRY/EXPOSE UNLOADED HANDGUN IN PUBLIC OR A VEHICLE(M)',
#        'CAUSE ELDER/DEPENDENT ADULT:HARM/DEATH',
#        'CAUSE FIRE OF STRUCTURE/FOREST LAND',
#        'CAUSE GREAT BODILY HARM/DEATH OF ELDER/DEPENDENT ADULT',
#        'CAUSE HARM/DEATH OF ELDER /DEPENDENT ADULT (F)',
#        'CAUSING FIRE OF INHABITED STRUCTURE/PROPERTY',
#        'CAUSING FIRE OF INHABITED STRUCTURE/PROPERTY (F)',
#        'CAUSING FIRE OF PROPERTY (M)',
#        'CAUSING FIRE OF STRUCTURE/FOREST LAND', 'COMMIT MAIL THEFT (M)',
#        'CONSUMPTION OR POSSESSION OF OPEN CONTAINER',
#        'CONTACT MINOR WITH INTENT SEX',
#        'CONTACT MINOR WITH INTENT SEX (F)',
#        'CONTINUOUS SEXUAL ABUSE OF CHILD (F)',
#        'CONV PERSON POSS/ETC FIREARM:PROBATION RESTRICTION (F)',
#        'CONVEY/SELL/ETC PERSONAL ID INFO WITH INTENT TO DEFRAUD (F)',
#        'CONVEY/SELL/ETC PERSONAL ID INFO WITH INTENT TO DEFRAUD (M)',
#        'CONVICTED FELON POSSESS/PURCHASE/USE/ETC TEAR GAS (F)',
#        'CONVICTED PERSON POSS/OWN/ETC FIREARM:PROBATION RESTRICTION (F)',
#        'CONVICTED PERSON POSSESS/ETC FIREARM:SPECIFIC PRIORS (F)',
#        'CONVICTED PERSON POSSESS/OWN/ETC FIREARM (F)',
#        'CRIME AGAINST NATURE/SODOMY',
#        'CRIMES AGAINST CHILDREN/LEWD OR LASCIVIOUS',
#        'CRUELTY TO CHILD WITH POSSIBLE INJURY OR DEATH',
#        'DAMAGE ETC/USE ETC/POWER CONNECTING LINES (F)',
#        'DAMAGE/REMOVE/USE/ETC POWER/PHONE/CABLE LINES',
#        'DEALER ALLOW/MISUSE OF SPECIAL PLATES (M)',
#        'DEFACE/ETC STRUCTURE WITH CHEMICALS/ETC',
#        'DEFRAUDING AN INKEEPER ($400 OR LESS)',
#        'DEFRAUDING AN INNKEEPER (MORE THAN $400)',
#        'DEFRAUDING AN INNKEEPER [$950 OR LESS] (M)',
#        'DELIVER DRUG PARAPHERNALIA (M)',
#        'DISCHARGE BB DEVICE IN GROSSLY NEGLIGENT MANNER',
#        'DISCHARGE BB DEVICE IN GROSSLY NEGLIGENT MANNER (M)',
#        'DISCHARGE LASER AT OCCUPIED AIRCRAFT (F)',
#        'DISORD CONDUCT/PEEPING TOM', 'DISORD CONDUCT/PROSTITUTION',
#        'DISORD CONDUCT/SOLICIT LEWD ACT',
#        'DISORD CONDUCT:PEEK INTO INHABITED BUILDING (Peeping) (M)',
#        'DISORD CONDUCT:PROSTITUTION (M)',
#        'DISORD CONDUCT:SOLICIT LEWD ACT (M)',
#        'DISORDERLY CONDUCT:  ALCOHOL',
#        'DISORDERLY CONDUCT:  DRUGS OR DRUGS WITH ALCOHOL',
#        'DISORDERLY CONDUCT: ALCOHOL',
#        'DISORDERLY CONDUCT: DRUGS OR DRUGS WITH ALCOHOL',
#        'DISORDERLY CONDUCT: PEEPING W/CAMERA UNDER/THRU CLOTHES',
#        'DISORDERLY CONDUCT:PEEPING THRU HOLE OR WITH INSTRUMENT (M)',
#        'DIVERSION OF FUNDS [OVER $2350] (F',
#        'DIVERSION OF MONEY OVER $1000', 'DRINK WHILE DRIVING',
#        'DRINKING IN CONTROLLED AREA',
#        'DRIVING UNDER INFLUENCE WITHIN 10 YEARS OF PRIOR FELONY DUI',
#        'DRIVING UNDER INFLUENCE WITHIN 10 YEARS OF PRIOR FELONY DUI (F)',
#        'DRIVING UNDER THE INFLUENCE W/ INJURY',
#        'DRUNK IN PUBLIC: ALCOHOL, DRUGS, COMBO OR TOLUENE (M)',
#        'DRUNK, PROTECTIVE CUSTODY', 'DUI .08 ALC:CAUSING BODILY INJ (F)',
#        'DUI .08 ALCOHOL CAUSING BODILY INJURY', 'DUI ALC/0.08 PERCENT (M)',
#        'DUI ALCOHOL', 'DUI ALCOHOL (M)', 'DUI ALCOHOL 0.08 PERCENT',
#        'DUI ALCOHOL 0.08 PERCENT W/PRIOR', 'DUI ALCOHOL AND DRUGS (M)',
#        'DUI ALCOHOL AND/OR DRUGS',
#        'DUI ALCOHOL DRUGS/DEATH CAUSING BODILY INJURY',
#        'DUI ALCOHOL/DRUG (M)',
#        'DUI ALCOHOL/DRUGS:CAUSING BODILY INJURY (F)',
#        'DUI ALCOHOL:  0.04% OR MORE W/INJURY WHILE DRIVING PASSENGER FOR HIRE',
#        'DUI ALCOHOL:  0.04% OR MORE WHILE DRIVING PASSENGER FOR HIRE',
#        'DUI ALCOHOL:CAUSING BODILY INJURY (F)',
#        'DUI ALCOHOL:CAUSING BODILY INJURY (M)', 'DUI DRUG (M)',
#        'DUI DRUG:CAUSING BODILY INJURY (F)', 'DUI DRUGS (M)',
#        'DUI DRUGS CAUSING BODILY INJURY (F)',
#        'DUI W/PRIOR SPECIFIC CONVICTIONS (F)',
#        'DUI/RECKLESS DRIVING W/PRIOR SPECIFIC CONVICTIONS',
#        'ELDER ABUSE/NEGLECT (M)',
#        'EXHIBIT DEADLY WEAPON (OTHER THAN FIREARM)',
#        'EXHIBIT DEADLY WEAPON OTHER THAN FIREARM (M)',
#        'EXHIBIT DEADLY WEAPON/FIREARM', 'EXHIBIT FIREARM',
#        'EXHIBIT FIREARM (M)',
#        'EXHIBIT FIREARM/DEADLY WEAPON TO RESIST ARREST (F)',
#        'EXHIBIT/DISPLAY DEADLY WEAPON TO RESIST ARREST',
#        'EXHIBIT/DISPLAY FIREARM PRESENCE RES. P.O.',
#        'FAIL PROVIDE REQUIRED REGISTRATION INFORMATION (M)',
#        'FAIL REG GAIN/LV RESID (F)', 'FAIL REG GAIN/LV RESID (M)',
#        'FAIL REGISTER WITH FELONY SEX OFFENDER PRIOR CONVICTION (F)',
#        'FAIL TO PAY FARE FOR PUBLIC TRANSIT SYSTEM (I)',
#        'FAILED TO REG AS SEX OFNDR-MISD',
#        'FAILURE TO REGISTER AS CONT SUBS OFFENDER (M)',
#        'FALSE IMPERSONATION', 'FALSE IMPERSONATION OF ANOTHER',
#        'FALSE INFORMATION/ETC TO PAWN BROKER/ETC',
#        'FALSE PERSATION OF ANOTHER (F)',
#        'FALSE PERSONATION OF ANOTHER:SPEC CIRC (F)',
#        'FALSE STATEMENT IN PRESCRIPTION/ETC (F)',
#        'FALSELY REPRESENT AS OWNER OF GUIDE DOG (M)',
#        'FELON BUY/POSSESS/USE STUN GUN (M)',
#        'FELON POSSESS/BUY/USE STUN GUN (M)',
#        'FELON/ADDICT/ETC POSSESS FIREARM (F)',
#        'FELON/ADDICT/POSSESS/ETC FIREARM (F)',
#        'FILE FALSE INS CLAIM FOR THEFT OF Mot Veh (F)',
#        'FORCIBLE PENETRATION W/OBJECT:VICTIM UNDER 10 YEARS OF AGE (F)',
#        'FORGE/ALTER NARCOTIC PRESCRIPTION (F)',
#        'FORGE/ETC PRESCRIPTIONS (F)',
#        'FRAUDULENT POSSESS/USE SCANNING DEVICE (M)',
#        'FRAUDULENT USE OF ACCESS CARD OR ACCOUNT INFORMATION (UNDER $400)',
#        'FRAUDULENTLY PERSONATE STATE/COUNTY/CITY EMPLOYEE (M)',
#        'FURNISH DANGEROUS DRUG/DEVICE WITHOUT PRESCRIPTION (M)',
#        'FURNISH MINOR WITH MARIJUANA (F)',
#        'FURNISH/ETC MINOR WITH MARIJUANA', "GET CREDIT/ETC OTHER'S ID (F)",
#        'GET CREDIT/ETC OTHERS ID', 'GET CREDIT/ETC:USE OTHERS ID',
#        'GIVE FALSE INFO TO PEACE OFCR',
#        'GIVE/TRANS/OFFER MARIJ 28.5 GRAMS OR UNDER (M)',
#        'GRAND THEFT (Mot Veh Theft) (F)', 'GRAND THEFT (Shoplifting) (F)',
#        'GRAND THEFT (Theft From Building) (F)',
#        'GRAND THEFT (Theft From Coin Oper Machine or Dev) (F)',
#        'GRAND THEFT (Theft From Mot Veh) (F)',
#        'GRAND THEFT (Theft of Mot Veh Parts/Acc) (F)',
#        'GRAND THEFT - ANIMAL (F)',
#        'GRAND THEFT / THEFT OF PERSONAL PROPERTY',
#        'GRAND THEFT : CONVERT REAL PROPERTY (OVER $950) (F)',
#        'GRAND THEFT AUTO (F)',
#        'GRAND THEFT BY EMPLOYEE/SERVANT/ETC ($950 OR MORE)',
#        'GRAND THEFT BY SERVANT/ETC [$950 OR MORE] (F)',
#        'GRAND THEFT FIREARM, ANIMAL, ETC.',
#        'GRAND THEFT FROM PERS (Pocket-Picking) (F)',
#        'GRAND THEFT FROM PERS (Purse-Snatching) (F)',
#        'GRAND THEFT FROM PERSON',
#        'GRAND THEFT OF ACCESS CARDS (4 OR MORE) (F)',
#        'GRAND THEFT,DOG VALUE $950 OR MORE', 'GRAND THEFT/UNSPECIFIED',
#        'GRAND THEFT: CARGO EXCEEDS $950',
#        'GRAND THEFT: VEHICLES, VESSELS/ETC (F)', 'GRAND THEFT:AUTO (F)',
#        'GRAND THEFT:DOG [OVER $950] (F)',
#        'GRAND THEFT:FIREARM OR FARM ANIMAL (Shoplifting) (F)',
#        'GRAND THEFT:FIREARM/ANIMAL (All Other Larceny) (F)',
#        'GRAND THEFT:FIREARM/ANIMAL (Theft From Building) (F)',
#        'GRAND THEFT:FIREARM/ANIMAL (Theft From Mot Veh) (F)',
#        'GRAND THEFT:FRUIT/FOWL/ETC [OVER $950] (F)',
#        'GRAND THEFT:MONEY/LABOR/PROPERTY (F)',
#        'GRAND THEFT:MONEY/LABOR/PROPERTY OVER $950',
#        'GRAND THEFT:STOLEN COPPER MATERIALS > $950 (F)',
#        'HARMFUL MATTER SENT/ETC W/INTENT TO SEDUCE MINOR',
#        'HARMFUL MATTER SENT/ETC W/INTENT TO SEDUCE MINOR (F)',
#        'HARMFUL MATTER SENT/ETC W/INTENT TO SEDUCE MINOR (M)',
#        'IDENTITY THEFT', 'ILL USE OF TEAR GAS/TEAR GAS WEAPON (M)',
#        'ILLEGAL POSS/ETC OF FIREARM BY PRIOR VIOLENT OFFENDER (F)',
#        'IMPERSONATE TO GET MONEY/FELONY',
#        'IMPERSONATE WITHOUT CONSENT:HARM/DEFRAUD/ETC:INTERNET WEBSITE (M)',
#        'IMPERSONATING A PEACE OFCR (M)',
#        'IMPERSONATING ANOTHER VIA THE INTERNET', 'INDECENT EXPOSURE',
#        'INDECENT EXPOSURE (M)',
#        'INFLICT CORPORAL INJURY ON SPOUSE/COHAB/GRLFRND W/PRIORS (F)',
#        'INFLICT CORPORAL INJURY ON SPOUSE/COHABITANT',
#        'INFLICT MINOR INJ UPON CHILD (F)',
#        'INFLICT SERIOUS INJ UPON A CHILD (F)',
#        'INJ/DESTROY INSURED PROP (F)',
#        'INTENT USE/SELL/TRANSFER ACCESS CARD W/O CONSENT:FRAUD',
#        'JUSTIFIABLE HOMICIDE BY PEACE OFFICER (N)',
#        'KEEP PLACE TO SELL/ETC NARCOTIC CNTL SUBSTANCE',
#        'KEEP PLACE TO SELL/ETC NARCOTIC CNTL SUBSTANCE (F)',
#        'KNOWINGLY USE PERSONAL IDENTIFYING INFO TO COMMIT A VIOLATION (F)',
#        'KNOWINGLY USE PERSONAL IDENTIFYING INFO TO COMMIT VIOLATION (M)',
#        'LEWD & LASCIVIOUS ACT W/CHILD 14/15:DEFENDANT 10 YRS OLDER 11D (F)',
#        'LEWD & LASCIVIOUS ACT W/CHILD 14/15:DEFENDANT 10 YRS OLDR',
#        'LEWD AND LASCIVIOUS ACTS WITH CHILD UNDER 14 W/FORCE/ETC (F)',
#        'LEWD AND LASCIVIOUS ACTS WITH CHILD UNDER 14 WITH FORCE/ETC',
#        'LEWD OR LASCIVIOUS ACTS W/CHILD UNDER 14 YEARS (F)',
#        'LEWD/LASCIVIOUS ACTS - CHILD UNDER 14 YEARS',
#        'LIKELY TO CAUSE HARM/DEATH OF ELDER /DEPENDENT ADULT (F)',
#        'LIQUOR ON SCHOOL PROPERTY',
#        'LOITER IN PUBLIC PLACE FOR ILLEGAL DRUG ACTIVITY (M)',
#        'LOITER:INTENT:PROSTITUTION', 'LOITER:INTENT:PROSTITUTION (M)',
#        'LOITERING TO COMMIT PROSTITUTION',
#        'MAKE FALSE FIN STATEMENT USING FICTITIOUS NAME (F)',
#        'MALICIOUS MISCHIEF/VANDALISM (FELONY)',
#        'MALICIOUS MISCHIEF/VANDALISM(MISDEMEANOR)',
#        'MANDATORY REPORTING ACTS OF CHILD ABUSE',
#        'MANUFACTURE OF CONTROLLED SUBSTANCES',
#        'MANUFACTURE/ETC CONTROLLED SUBSTANCE',
#        'MANUFACTURE/IMPORT/POSSESS/ETC SHORT-BARRELED RIFLE/SHOTGUN (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC CANE SWORD (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC LARGE CAPACITY MAGAZINE (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC LEADED CANE/BILLY/ETC (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC LEADED CANE/BILLY/ETC (M)',
#        'MANUFACTURE/SALE/POSSESS/ETC METAL KNUCKLES (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC METAL KNUCKLES (M)',
#        'MANUFACTURE/SALE/POSSESS/ETC NUNCHAKU (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC SHURIKEN (F)',
#        'MANUFACTURE/SALE/POSSESS/ETC WRITING PEN KNIFE (F)',
#        'MANUFACTURE/SELL FALSE DOCUMENTS',
#        'MANUFACTURE/SELL/ETC:LARGE CAPACITY MAGAZINE (F)',
#        'MANUFACTURE/SELL/POSSESS DANGEROUS WEAPONS/EXPLOSIVES/ETC',
#        'MAYHEM', 'MAYHEM (F)', 'MFG/ETC LEADED CANE/BILLY/SAP ETC (M)',
#        'MFG/ETC LEADED CANE/BILLY/SAP, ETC (F)',
#        'MFG/ETC LEADED CANE/ETC (F)', 'MFG/SALE/ETC CANE SWORD (M)',
#        'MFG/SALE/ETC METAL KNUCKLES (F)',
#        'MFG/SALE/ETC METAL KNUCKLES (M)', 'MFG/SALE/POSS SHURIKEN (M)',
#        'MFG/SALE/POSSESS NUNCHAKU (F)',
#        'MFG/SELL 1000 OR MORE COUNTERFEIT REG MARK (F)',
#        'MFG/SELL 1000 OR MORE COUNTERFEIT REG MARK ) (M)',
#        'MFG/SELL UNDER 1000 COUNTERFEIT REG MARK (M)',
#        'MFG/SELL/TRANS/ETC ASSAULT WEAPON (F)',
#        'MINOR CONSUMING ALCOHOL - NOT IN PUBLIC',
#        'MINOR CONSUMING ALCOHOL IN PUBLIC',
#        'MINOR DRIVER TRANSPORTING ALCOHOL, NOT JOB RELATED',
#        'MINOR ILLEGALLY POSSESS CONCEALED WEAPON WITH PRIOR (F)',
#        'MINOR PASSENGER IN VEHICLE POSSESSING ALCOHOL',
#        'MINOR POSS ALC (M)',
#        'MINOR POSS MARIJ ON GROUNDS DURING SCH ACTIVITIES (M)',
#        'MINOR POSSESS ALCOHOL',
#        'MINOR POSSESS MARIJUANA ON GROUNDS DURING SCHOOL ACTIVITIES',
#        'MINOR PURCHASE/ETC LIQUOR IN BAR', 'MINOR STEALING MERCHANDISE',
#        'MINOR UNDER 18 POSS SPRAY PAINT ON PUBLIC HWY (M)',
#        'MINOR/POSSESS/PURCHASE/ETC:TEAR GAS/TEAR GAS WEAPON (M)',
#        'MINOR:KNOWINGLY OPER VEH W/CARRYING ALC (M)', 'MURDER',
#        'MURDER (F)', 'MURDER - DEGREE NOT SPECIFIED',
#        'NARCOTIC ADDICT POSSESS/PURCHASE/USE TEAR GAS OR T/G WEAP',
#        'NARCOTIC ADDICT POSSESS/PURCHASE/USE/ETC TEARGAS/TEARGAS (M)',
#        'OBSTRUCT/RESIST EXECUTIVE OFFICER',
#        'OBSTRUCT/RESIST EXECUTIVE OFFICER WITH MINOR INJURY (F)',
#        'OBSTRUCT/RESIST EXECUTIVE OFFICER WITH SERIOUS INJURY (F)',
#        'OBSTRUCT/RESIST PUB OFFICER',
#        'OBSTRUCT/RESIST/DELAY PUBLIC PEACE OFFICE OR EM TECH.',
#        'OBTAIN CREDIT/ETC:USE OTHERS ID',
#        'OBTAIN MONEY,ETC. BY FALSE PRETENSES (OVER $400)',
#        'OBTAIN MONEY/ETC BY FALSE PRETENSES ($950 OR LESS)',
#        'OBTAIN MONEY/ETC BY FALSE PRETENSES [$950 OR LESS] (M)',
#        'OBTAIN MONEY/ETC BY FALSE PRETENSES [OVER $950] (F)',
#        'OBTAIN MONEY/ETC BY FALSE PRETENSES \xa1OVER $950+',
#        'OCCUPANT CARRY CONCEALABLE WEAPON IN VEHICLE:SPECIFIC CIR',
#        'OPEN ALCOHOLIC BEV CONTAINERS PROHIBITED ON POSTED CONTAINERS',
#        'OPEN ALCOHOLIC BEVERAGE IN CITY LOT.',
#        'OPEN CONTAINER IN PUBLIC PARK',
#        'ORAL COP:VICTIM UNCONSCIOUS OR ASLEEP', 'ORAL COPULATION',
#        'ORAL COPULATION BY FORCE OR FEAR',
#        'ORAL COPULATION W/FORCE OR FEAR (F)',
#        'ORAL COPULATION W/PERSON UNDER 18 YEARS (F)',
#        'ORAL COPULATION WHILE CONFINED IN PRISON/JAIL (F)',
#        'ORAL COPULATION:VIC INCAPABLE OF CONSENT (F)',
#        'ORAL COPULATION:VICTIM UNDER 10 YEARS OF AGE (F)',
#        'P0SSESS BLANK CHECK:DEFRAUD (F)', 'PANDERING',
#        'PASSENGER:MINOR:POSS ALC IN VEH (M)',
#        'PERSON DIRECT/SUPERVISE/ETC ANOTHER IN PROSTITUTION',
#        'PERSON KNOWINGLY MANAGE PLACE FOR CONTROLLED SUBSTANCE USE',
#        'PERSONATE TO GET MONEY/PROP [$400 OR LESS] (M)',
#        'PERSONATE TO GET MONEY/PROP [OVER $400] (F)',
#        'PERSONATE TO MAKE OTHER LIABLE',
#        'PERSONATE TO MAKE OTHER LIABLE (F)',
#        'PERSONATE TO MAKE OTHER LIABLE (M)', 'PETTY THEFT',
#        'PETTY THEFT -- UNDER $950',
#        'PETTY THEFT / THEFT OF PERSONAL PROPERTY / SHOPLIFT',
#        'PETTY THEFT FROM LIBRARY OR MERCHANT (M)',
#        'PETTY THEFT W/PR JAIL TERM (Shoplifting) (F)',
#        'PETTY THEFT W/PR JAIL TERM (Theft From Building) (F)',
#        'PETTY THEFT W/PR JAIL TERM (Theft From Mot Veh) (F)',
#        'PETTY THEFT W/PRIOR JAIL TERM FOR SPECIFIC OFFENSES',
#        'PETTY THEFT(All Other Larceny) (M)',
#        'PETTY THEFT(Mot Veh Parts) (M)', 'PETTY THEFT(Pocket Picking) (M)',
#        'PETTY THEFT(Purse Snatch) (M)', 'PETTY THEFT(Shoplift) (M)',
#        'PETTY THEFT(from Building) (M)',
#        'PETTY THEFT(from Coin Oper Machine) (M)',
#        'PETTY THEFT(from Veh) (M)', 'PETTY THEFT- RETAIL MERCHANDISE',
#        'PETTY THEFT:DOG [$950 OR LESS] (M)', 'PIMPING', 'PIMPING (F)',
#        'PLANT/CULTIVATE/ETC MARIJUANA/HASHISH (F)',
#        'POS IN AIRPORT:STUN GUN (M)', 'POSS CNTL SUB W/O PRESCRIPTION (M)',
#        'POSS CONCENTRATED CANNABIS (F)',
#        'POSS CONT SUBS WHILE ARMED W/LOADED FIREARM (F)',
#        'POSS CONTRL SUB PARAPHERNALIA', 'POSS CONTROLLED SUBS (F)',
#        'POSS CONTROLLED SUBS FOR SALE (F)',
#        'POSS CONTROLLED SUBS PARAPHERNALIA (M)',
#        'POSS CONTROLLED SUBSTANCE FOR SALE',
#        'POSS FIREARM W/ALTERED IDENT (F)',
#        'POSS FOR SALE DESIGNATED CONTROLLED SUBSTANCE',
#        'POSS FOR SALE DESIGNATED CONTROLLED SUBSTANCE (F)',
#        'POSS FOR SALE VALIUM, LIBRIUM, ETC (NON-NARCOTIC)',
#        'POSS FOR SALE/SELL CONT SUBS KETAMINE (F)',
#        'POSS FOR SALE/SELL CONTROLLED SUBS (F)',
#        'POSS MARIJUANA FOR SALE (F)', 'POSS MARIJUANA OVER 28.5 GRAMS (M)',
#        'POSS NARCOTIC CONTROLLED SUBS (F)',
#        'POSS NARCOTIC CONTROLLED SUBS (M)',
#        'POSS OBSCENE MATTER:MINOR IN SEXUAL ACTS (M)',
#        'POSS OF ACCESS CARD W/INTENT TO USE/SELL/TRSFR (M)',
#        'POSS OPEN CONTAINER OF ALC IN PUBLIC (I)',
#        'POSS OPEN CONTAINER WHILE DRVG (I)',
#        'POSS PHENCYCLIDINE/ETC FOR SALE (F)',
#        'POSS SWITCHBLADE:VEHICLE (M)',
#        'POSS TOOL WITH INTENT TO VANDALIZE (M)',
#        'POSS WEAPON AT SCHOOL (F)', 'POSS/ETC BASE/ROCK COCAINE F/SALE',
#        'POSS/PURCHASE COCAINE BASE FOR SALE (F)',
#        'POSS/USE FALSE EVID OF AGE', 'POSS/USE FALSE EVIDENCE OF AGE (M)',
#        'POSSES MARIJUANA FOR SALE OVER 18 (M)',
#        'POSSESS CONCENTRATED CANNABIS',
#        'POSSESS CONCENTRATED CANNABIS (M)', 'POSSESS CONTROLLED SUBSTANCE',
#        'POSSESS CONTROLLED SUBSTANCE (F)',
#        'POSSESS CONTROLLED SUBSTANCE (M)',
#        'POSSESS CONTROLLED SUBSTANCE WITHOUT PRESCRIPTION',
#        'POSSESS CONTROLLED SUBSTANCE:NO PRIOR CONVICTION',
#        'POSSESS CONTROLLED SUBSTANCES WITHOUT A PRESCRIPTION (M)',
#        'POSSESS DRILL/ETC WITH INTENT TO VANDALIZE',
#        'POSSESS FOR SALE/SELL CONTROLLED SUBSTANCE',
#        'POSSESS ID OF 10 OR MORE PERSONS WITH INTENT TO DEFRAUD (F)',
#        'POSSESS MARIJUANA 1 OZ OR  LESS WHILE DRIVING',
#        'POSSESS MARIJUANA 1 OZ OR LESS WHILE DRIVING (I)',
#        'POSSESS MARIJUANA 28.5 GRAMS OR LESS OR W/NO PRIOR',
#        'POSSESS MARIJUANA FOR SALE W/ PRIOR 11359 CONVICTIONS (F)',
#        'POSSESS MARIJUANA OVER 28.5 GRAMS',
#        'POSSESS MARIJUANA/HASHISH FOR SALE',
#        'POSSESS NARCOTIC CONTROLLED SUBSTANCE (F)',
#        'POSSESS OF AMMUNITION BY PROHIBITED PERSON (F)',
#        'POSSESS OPEN CONTAINER WHILE DRIVING',
#        'POSSESS PERSONAL IDENTIFYING INFO WITH INTENT TO DEFRAUD',
#        'POSSESS PERSONAL IDENTIFYING INFO WITH INTENT TO DEFRAUD (M)',
#        'POSSESS SPECIFIED CONTROLLED SUBSTANCE DEVICE/ETC.',
#        'POSSESS SWITCHBLADE IN VEHICLE (M)', 'POSSESS SYRINGE',
#        'POSSESS UNLAWFUL PARAPHERNALIA (M)',
#        'POSSESS WEAPON IN AIRPORT STERILE AREA OR PASSENGER VESSEL TERMINAL (M)',
#        'POSSESS WEAPON/ETC AT SCHOOL', 'POSSESS WEAPON/ETC AT SCHOOL (M)',
#        'POSSESS WEAPON/ETC ON CAMPUS:NOT FIREARM',
#        'POSSESS WEAPON/ETC ON CAMPUS:NOT FIREARM (M)',
#        'POSSESS/ETC FIREARM W/PR VIOLENT OFFENSE CONVICTION (F)',
#        'POSSESS/ETC OBSCENE MATTER OF MINOR IN SEXUAL ACT (F)',
#        'POSSESS/EXPLODE DESTRUCTIVE DEVICE W/ INTENT TO INJURE OR DESTROY (F)',
#        'POSSESS/FURNISH SYNTHETIC CANNABINOID (M)',
#        'POSSESS/MANUFACTURE/COMMERCIAL SALE COMPOSITE/WOOD KNUCKLES (M)',
#        'POSSESS/PURCHASE FOR SALE NARCOTIC/CONTROLLED SUBSTANCE (F)',
#        'POSSESS/PURCHASE/ETC PROJECTILE TEAR GAS WEAPON (F)',
#        'POSSESS/SELL SHORT-BARRELED SHOTGUN OR RIFLE',
#        'POSSESSION OF LESS THAN 28.5 GRAMS OF MARIJUANA DURING K-12 SCHOOL - OVER 18 (M)',
#        'POSSESSION OF LESS THAN 28.5 GRAMS OF MARIJUANA DURING K-12 SCHOOL -UNDER 18 (I)',
#        'POSSESSION OF MORE THAN 28.5 GRAMS OF MARIJUANA - 18-21 YEARS OLD (M)',
#        'POSSESSION OF NARCOTIC CONTROLLED SUBSTANCES (M)',
#        'POSSESSION OF SUBSTANCES TO SELL OR FURNISH METH (F)',
#        'POSSESSION OF UP TO AN OUNCE OF MARIJUANA (I)',
#        'PREVENT OR DISSUADE WITNESS/VICTIM W/FORCE',
#        'PREVENT/DISSUADE WIT VIC BY THREAT/FORCE (F)',
#        'PREVENT/DISSUADE WITNESS/VICTIM W/ FORCE/THREAT',
#        'PRISONER POSS WEAPON (F)', 'PROCESS CONCENTRATED CANNABIS (M)',
#        'PROHIBITED PERSON OWN/POSSESS/ETC AMMUNITION/ETC (F)',
#        'PROHIBITED PERSON OWN/POSSESS/ETC AMMUNITION/ETC (M)', 'RAPE',
#        'RAPE BY FEAR OR FORCE', 'RAPE BY FORCE/FEAR (F)',
#        'RAPE OF DRUGGED VIC (F)', 'RAPE OF DRUGGED VICTIM',
#        'RAPE OF SPOUSE UNDER CONTROLLED SUB/ETC, UNABLE TO RESIST',
#        'RAPE SPOUSE BY FORCE/FEAR/ETC',
#        'RAPE/ETC IN CONCERT WITH FORCE/VIOLENCE:MINOR 14 YRS OR OLDER (F)',
#        'RAPE: FORCE/FEAR/ETC.', 'RAPE: VICTIM DRUGGED',
#        'RAPE: VICTIM INCAPABLE OF CONSENT',
#        'RAPE:VIC INCAPABLE OF GIVING CONSENT (F)',
#        'RAPE:VICTIM NOT AWARE ACT OCCURRED (F)',
#        'RAPE:VICTIM SUBMITS UNDER BELIEF PERSON IS KNOWN TO THEM (F)',
#        'RAPE:VICTIM UNCONSCIOUS OF THE NATURE OF THE ACT',
#        'RAPE:VICTIM WAS UNCONSCIOUS OR ASLEEP (F)',
#        'REMOVE PART OF REALTY',
#        'RENT/ETC FOR STORAGE/SALE OF CONT SUBS (F)',
#        'RESIST PEACE OFCR RSLT IN DEATH/INJ (F)',
#        'RESISTS PEACE OFFICER CAUSE DEATH/SBI', 'ROBBERY', 'ROBBERY (F)',
#        'ROBBERY: FIRST DEGREE',
#        'ROBBERY: FIRST DEGREE: INHABITED DWELLING: IN CONCERT W/OTHER',
#        'ROBBERY: SECOND DEGREE',
#        'SELL ALCOHOLIC BEVERAGE TO INTOXICATED PERS (M)',
#        'SELL LIQUOR TO MINOR (M)', 'SELL LIQUOR W/O LICENSE',
#        'SELL/ETC IN LIEU OF CONTROLLED SUBSTANCE',
#        'SELL/ETC LIQUOR TO MINOR', 'SELL/FURNISH MARIJUANA/HASHISH (F)',
#        'SELL/FURNISH/GIVE/TRANSPORT/ETC MARIJUANA OVER 28.5 GRAMS',
#        'SELL/TRANSFERS/ETC ACCESS CARD W/O CONSENT',
#        'SEND/BRING WEAP/TEAR GAS INTO PRISON/JAIL (F)',
#        'SEND/EXHIBIT/ETC HARMFUL MATTER TO MINOR:INTENT TO SEDUCE',
#        'SEND/SELL OBSCENE MATTER DEPICTING MINOR (F)',
#        'SEND/SELL/ETC OBSCENE MATTER DEPICTING MINOR',
#        'SEX OFFENDER FAIL TO REGISTER/ETC (M)',
#        'SEX OFFENDER FAIL UPDATE ANNUAL REGISTRATION (F)',
#        'SEX PENETRATION:FOREIGN OBJ/ETC VICTIM UNAWARE:NATURE OF',
#        'SEX PENETRATION:FOREIGN OBJ/ETC:VICTIM UNCONSCIOUS/ASLEEP (F)',
#        'SEX PENETRATION:FRGN OBJ VIC UNAWARE:NATURE OF ACT (F)',
#        'SEX REGISTRANT FAIL REPORT ADDRESS CHANGE (F)', 'SEXUAL BATTERY',
#        'SEXUAL BATTERY (F)', 'SEXUAL BATTERY (M)',
#        'SEXUAL BATTERY OF RESTRAINED OR INCAPACITATED PERSON (F)',
#        'SEXUAL BATTERY ON INSTITUTIONALIZED PERSON',
#        'SEXUAL BATTERY ON MED INSTITUTIONALIZED PERS (F)',
#        'SEXUAL PENETRATION W/ FOREIGN OBJECT W/ FORCE',
#        'SEXUAL PENETRATION W/FORCE/ETC 14 YEARS OR OLDER',
#        'SEXUAL PENETRATION W/FORCE/ETC UNDER 14 YEARS OLD',
#        'SEXUAL PENETRATION W/FORCE/FEAR/ETC (F)',
#        'SEXUAL PENETRATION W/FOREIGN OBJECT: VIC BELIEVES IS SPOUSE',
#        'SEXUAL PENETRATION W/FRGN OBJ:VIC INCAPABLE CONSENT (F)',
#        'SEXUAL PENETRATION:FOREIGN OBJECT/ETC:VICTIM UNDER 18 YEARS (F)',
#        'SHOOT AT INHABITED DWELLING/VEH (F)',
#        'SHOOT AT INHABITED DWELLING/VEHICLE/ETC', 'SHOPLIFT BURGLARY',
#        'SHOPLIFTING (M)',
#        'SIMPLE ASSAULT ON PERSON ON SCHOOL OR PARK PROPERTY (M)',
#        'SIMPLE BATTERY (M)', 'SODOMY BY FORCE OR FEAR',
#        'SODOMY BY FORCE/VIOLENT/FEAR (F)',
#        'SODOMY W/PERS UNDER 16 YEARS (F)',
#        'SODOMY WHILE CONFINED IN PRISON/JAIL (F)',
#        'SODOMY/VICTIM UNCONSCIOUS OF THE NATURE OF ACT',
#        'SODOMY:MINOR UNDER 14 & 10+ YEARS YOUNGER',
#        'SODOMY:VIC UNCONSCIOUS OF THE NATURE OF THE ACT (F)',
#        'SODOMY:VICTIM UNDER 10 YEARS OF AGE',
#        'SODOMY:VICTIM UNDER 10 YEARS OF AGE (F)',
#        'SODOMY:VICTIM UNDER INFLUENCE ANESTHETIC/ETC/ANY CONTROL S',
#        'SOLICIT/ETC BUSINESS THROUGH FALSE INSURANCE CLAIM',
#        'SPOUSAL/COHABITANT ABUSE WITH MINOR INJURY (F)',
#        'SPOUSAL/COHABITANT ABUSE WITH SERIOUS INJURY (F)',
#        'SUBMIT CLAIM FOR HEALTH BENEFITS NOT USED BY CLAIMANT [OVER $950] (F)',
#        "TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT",
#        "TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT (F)",
#        'TAKE VEHICLE WITHOUT OWNER CONSENT WITH SPECIFIC PRIORS (F)',
#        'TAKE VESSEL WITHOUT OWNER PERMISSION (M)', 'TAMPER WITH AUTO',
#        'TAMPER WITH VEH', 'TEMPORARY ALCOHOL BAN', 'TERRORIST THREATS',
#        'TERRORIST THREATS THAT THREATEN FAMILY', 'THEFT', 'THEFT (M)',
#        'THEFT BY FORGED/INVALID CREDIT CARD (OVER $950)',
#        'THEFT BY FORGERY/INVALID CREDIT CARD (LESS THAN $950)',
#        'THEFT BY MISREPRESENTATION AS CREDIT CARD HOLDER (OVER $950)',
#        'THEFT BY MISREPRESENTATION AS CREDIT CARD HOLDER (UNDER $950)',
#        'THEFT BY USE OF ACCESS CARD INFORMATION [$950 OR LESS] (M)',
#        'THEFT BY USE OF ACCESS CARD INFORMATION [OVER $950] (F)',
#        'THEFT BY USE OF CREDIT CARD (UNDER $950)',
#        'THEFT NOT EXCEEDING $950 (M)', 'THEFT OF CREDIT CARD/CARD NOT OWN',
#        'THEFT OF UTILITY SERVICES', 'THEFT OF UTILITY SERVICES (M)',
#        'THEFT/NON-RETURN OF RENTAL PROPERTY',
#        'THIRD DUI CONVICTION WITHIN 10 YEARS',
#        'THREATEN CRIME W/INTENT TO TERRORIZE (F)',
#        'THREATEN CRIME WITH INTENT TO TERRORIZE',
#        'THREATEN CRIME WITH INTENT TO TERRORIZE (F)',
#        'THREATEN CRIME WITH INTENT TO TERRORIZE (M)',
#        'THREATEN EXECUTIVE OFFICER WITH VIOLENCE (F)',
#        'THREATEN SCHOOL/PUBLIC OFCR/EMPLOYEE (F)',
#        'THREATEN SCHOOL/PUBLIC OFFICER/EMPLOYEE',
#        'THROW SUBS AT VEH ON HWY (M)',
#        'THROW SUBS AT VEH ON HWY W/GBI INTENT (F)',
#        'THROW SUBSTANCE AT VEHICLE WITH GBI INTENT',
#        'THROW/SHOOT/ETC OBJECT AT MULTI-PASSENGER TRAIN/BOAT/VEHICLE',
#        'TOUCH PERSON INTIMATELY AGAINST WILL FOR SEXUAL AROUSAL/E',
#        'TOUCH PERSON INTIMATELY AGAINST WILL FOR SEXUAL AROUSAL/ETC (M)',
#        'TRANS FOR SALE CONT SUBS BETWEEN COUNTIES (F)',
#        'TRANS/ETC CONTROLLED SUBS (F)',
#        'TRANS/SELL NARCOTIC/CONTROLLED SUBS (F)',
#        'TRANSIENT FAIL 30 DAY UPDATE OF REGISTRATION (M)',
#        'TRANSIENT FAILS TO REGISTER WHEN RELEASED FROM CUSTODY (F)',
#        'TRANSPORT/SELL CONTROLLED SUBSTANCE',
#        'TRANSPORT/SELL NARC CONTROLLED SUBSTANCE BETWEEN COUNTIES',
#        'TRANSPORT/SELL NARCOTIC/CONTROLLED SUBSTANCE',
#        'UNAUTH TAKE BIKE/BOAT/VESSEL FOR TEMP USE (M)',
#        'UNAUTHORIZED USE OF PERSONAL IDENTIFICATION:OBTAIN CREDIT',
#        'UNDER INFL OF SPEC CONT SUBS:POSS FIREARM (F)',
#        'UNDER INFLUENCE OF SPECIAL CONTROLLED SUBSTANCE: POSSESS FIREARM',
#        'UNL SEX INTERCOURSE W/MINOR:MORE THAN 3 YRS YOUNGER (F)',
#        'UNLAWFUL CAUSE FIRE OF PROPERTY',
#        'UNLAWFUL POSSESS/USE TEAR GAS OR TEAR GAS WEAPON:EX FEL/ETC (M)',
#        'UNLAWFUL POSSESSION/CONTROLLED SUBSTANCE WHILE IN POSS/FIREARM',
#        'UNLAWFUL SEXUAL INTERCOURSE / VICTIM UNDER 18',
#        'UNLAWFUL SEXUAL INTERCOURSE W / MINOR 18',
#        'UNLAWFUL SEXUAL INTERCOURSE W/MINOR 18 (F)',
#        'UNLAWFUL SEXUAL INTERCOURSE W/MINOR: MORE THAN 3 YEARS OLD',
#        'UNLAWFUL SEXUAL INTERCOURSE W/MINOR: PERP 21+ VICTIM -16',
#        'UNLAWFUL SEXUAL INTERCOURSE W/MINOR:3 YRS OLDER OR YOUNGER (M)',
#        'UNLIC SALE/LOAN/TRANSFER OF FIREARM (F)',
#        'USE ACCESS CARD ACCOUNT INFO W/O CONSENT (F)',
#        'USE ANOTHER PERSONAL IDENTIFICATION TO OBTAIN CREDIT/ETC',
#        'USE FALSE CITIZENSHIP/ETC DOCUMENTS (F)',
#        'USE OTHERS ID WITH INTENT DEFRAUD:WITH PRIOR CONVICTION',
#        'USE OTHERS ID WITH INTENT DEFRAUD:WITH PRIOR CONVICTION (F)',
#        'USE OTHERS ID WITH INTENT DEFRAUD:WITH PRIOR CONVICTION (M)',
#        'USE WATERCRAFT WITH BLOOD ALCOHOL OF .08% (OR MORE) (M)',
#        'USE/ACCESS CREDIT CARD ACCOUNT INFORMATION W/O CONSENT',
#        'USE/ETC EXPLOSIVE/ETC DEVICE WITH INTENT TO INJURE/ETC (F)',
#        'USE/UNDER INFL OF CONTROLLED SUBS (M)',
#        'USE/UNDER INFLUENCE OF CONTROLLED SUBSTANCE',
#        'VANDALISM ($1000-$5000)', 'VANDALISM ($400 OR MORE)',
#        'VANDALISM ($400 OR MORE) (F)', 'VANDALISM ($5000-$50000)',
#        'VANDALISM (LESS THAN $1000)', 'VANDALISM (LESS THAN $400)',
#        'VANDALISM (LESS THAN $400) REPEAT OFFENSE',
#        'VANDALISM [$400 OR LESS] (M)',
#        'VANDALISM:DAMAGE PROPERTY (MISDEMEANOR)',
#        'VANDALISM:DEFACE PROPERTY (MISDEMEANOR)',
#        "VANDALISM:DESTROY OTHER'S PROPERTY",
#        'VANDALIZE PLACE OF WORSHIP (F)',
#        'VEH DRIVER/OWNER PERMIT OTHER CARRY/ETC FIREARM INTO VEHICLE',
#        'VEH THEFT:SPECIFIC PRS (F)', 'VEHICLE/ETC THEFT :SPECIFIC PRIORS',
#        'VIOLATE CIVIL RIGHTS BY FORCE OR THREAT',
#        'VIOLATE CIVIL RIGHTS BY THREAT OF FORCE (M)',
#        'VIOLATE CIVIL RIGHTS W/INJURY OR PROPERTY DAMAGE > $500',
#        'VIOLATE CIVIL RIGHTS: CAUSE MINOR INJURY (M)',
#        'W/INTENT TO DEFRAUD ACQUIRE ID OF PERS DEPLOYD OUT OF COUNTRY',
#        'WEAPONS RESTRICTIONS VIOL:MENTALLY DISORDERED PERS (F)',
#        'WILFUL POISONNING/ETC OF FOOD/ECT (F)',
#        'WILLFUL CRUELTY TO CHILD NO GBI (M)',
#        'WILLFUL CRUELTY TO CHILD WITHOUT INJURY OR DEATH (F)',
#        'WILLFUL CRUELTY TO CHILD: WITH INJURY/DEATH (F)',
#        'WILLFUL CRUELTY TO CHILD:POSSIBLE INJURY/DEATH',
#        'WILLFUL DISCHARGE OF FIREARM IN A GROSSLY NEGLIGENT MANNER',
#        'WILLFUL DISCHARGE OF FIREARM IN A GROSSLY NEGLIGENT MANNER (F)'], dtype=object)

# %%
# Create the final crime dict for the 2016 data
unique_months = np.unique(df_records_2016['month'])
unique_offenses = np.unique(df_records_2016['offense'])

# Loop through each month
for m, month in enumerate(unique_months):
    # Loop through each day
    df_month = df_records_2016[df_records_2016['month']==month]
    unique_days = np.unique(df_month['day'])
    for d, day in enumerate(unique_days):
        # Loop through each offense
        for o, offense in enumerate(unique_offenses)

# %%
# Format data to count the number of events that occured each day
df_records_2017.head(20)
# Filter by each year-month-day combination
# Out:
#     day month                                            offense  year
# 52    1     1                   POSSESS CONTROLLED SUBSTANCE (M)  2017
# 143   1     3         DEFRAUDING AN INNKEEPER [$950 OR LESS] (M)  2017
# 221   1     2                           VANDALISM ($400 OR MORE)  2017
# 305   1     3  DRUNK IN PUBLIC: ALCOHOL, DRUGS, COMBO OR TOLU...  2017
# 307   1     3                        ADW WITH FORCE:POSSIBLE GBI  2017
# 310   1     2                             BURGLARY/SECOND DEGREE  2017
# 311   1     2     TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT  2017
# 312   1     3     TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT  2017
# 314   1     4                         BURGLARY (SHOPLIFTING) (M)  2017
# 315   1     5                         VANDALISM (LESS THAN $400)  2017
# 337   1     1                         VANDALISM (LESS THAN $400)  2017
# 339   1     1                              BURGLARY/FIRST DEGREE  2017
# 340   1     2           RAPE:VIC INCAPABLE OF GIVING CONSENT (F)  2017
# 341   1     2                DISORD CONDUCT:SOLICIT LEWD ACT (M)  2017
# 342   1     4                                    SHOPLIFTING (M)  2017
# 343   1     7                         VANDALISM (LESS THAN $400)  2017
# 344   1     8                                        PETTY THEFT  2017
# 345   1     9     TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT  2017
# 346   1    10                                        PETTY THEFT  2017
# 349   1     5     TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT  2017

# %%
#

# %%
records_dict.keys()
# Out:
# ['offense', 'month', 'day', 'year']

# %%
# Update csv of 2017 data
